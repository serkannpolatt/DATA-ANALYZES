# %%
import pandas as pd

# %%
data=pd.read_csv("mito.csv")

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year
# ...

# %% [markdown]
# CHECKİNG SHAPE OF DATASET
#
# #VERİ SETİ ŞEKLİ KONTROL ETMEK

# %%
data.shape
# Out:
# (51290, 14)

# %% [markdown]
# ADDİNG A NEW COLUMN
#
# #YENİ BİR SÜTUN EKLEME

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year
# ...

# %%
data["new_quantity"]=data["quantity"]*10

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %% [markdown]
# ADDİNG A NEW COLUMN A PARTİCULAR PLACE
#
# #BELİRLİ BİR YER YENİ SÜTUN EKLEME

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %%
data.insert(10, "new_sales", data.sales*100)

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales                                          new_sales  quantity  \
# ...

# %% [markdown]
# DELETE A COLUMN
#
# #BİR SÜTUNU SİL

# %%
data.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales                                          new_sales  quantity  \
# ...

# %%
data.drop("customer_name",axis=1)
# Out:
#               order_id  order_date      segment        country   region  \
# 0         AG-2011-2040  01-01-2011     Consumer        Algeria   Africa
# 1        IN-2011-47883  01-01-2011     Consumer      Australia  Oceania
# 2         HU-2011-1220  01-01-2011     Consumer        Hungary     EMEA
# 3      IT-2011-3647632  01-01-2011  Home Office         Sweden    North
# 4        IN-2011-47883  01-01-2011     Consumer      Australia  Oceania
# ...                ...         ...          ...            ...      ...
# 51285   CA-2014-115427  12/31/2014    Corporate  United States     West
# 51286     MO-2014-2560  12/31/2014     Consumer        Morocco   Africa
# 51287   MX-2014-110527  12/31/2014     Consumer      Nicaragua  Central
# 51288   MX-2014-114783  12/31/2014     Consumer         Mexico    North
# 51289   CA-2014-156720  12/31/2014     Consumer  United States     West
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# ...

# %%
data.drop("customer_name",axis=1,inplace=True) #deleting a column permanently

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %% [markdown]
# SORTİNG A DATAFRAME
#
# #BİR VERİ ÇERÇEVESİ SIRALAMA

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
data.sort_values(by="profit") # sorting - by default -in Ascending order
# Out:
#              order_id  order_date      segment        country   region  \
# 31884  CA-2013-108196  11/26/2013     Consumer  United States     East
# 29212    TU-2013-9400   9/26/2013    Corporate         Turkey     EMEA
# 47195  US-2014-168116  11-05-2014    Corporate  United States    South
# 3775   CA-2011-169019   7/26/2011     Consumer  United States  Central
# 37130  CA-2014-134845   4/18/2014  Home Office  United States     West
# ...               ...         ...          ...            ...      ...
# 5522   CA-2011-116904   9/23/2011     Consumer  United States  Central
# 33011  CA-2013-117121  12/18/2013     Consumer  United States  Central
# 48097  CA-2014-166709  11/18/2014     Consumer  United States     East
# 36239  CA-2014-140151   3/24/2014     Consumer  United States     West
# 29530  CA-2013-118689  10-03-2013    Corporate  United States  Central
#
#              product_id         category  \
# 31884   TEC-MA-10000418       Technology
# ...

# %%
data.sort_values(by="profit",ascending=False)
# Out:
#              order_id  order_date      segment        country   region  \
# 29530  CA-2013-118689  10-03-2013    Corporate  United States  Central
# 36239  CA-2014-140151   3/24/2014     Consumer  United States     West
# 48097  CA-2014-166709  11/18/2014     Consumer  United States     East
# 33011  CA-2013-117121  12/18/2013     Consumer  United States  Central
# 5522   CA-2011-116904   9/23/2011     Consumer  United States  Central
# ...               ...         ...          ...            ...      ...
# 37130  CA-2014-134845   4/18/2014  Home Office  United States     West
# 3775   CA-2011-169019   7/26/2011     Consumer  United States  Central
# 47195  US-2014-168116  11-05-2014    Corporate  United States    South
# 29212    TU-2013-9400   9/26/2013    Corporate         Turkey     EMEA
# 31884  CA-2013-108196  11/26/2013     Consumer  United States     East
#
#              product_id         category  \
# 29530   TEC-CO-10004722       Technology
# ...

# %% [markdown]
# FİLTER DATAFRAME (SİNGLE COLUMN / CONDİTİON)
#
# #FİLTRE VERİ ÇERÇEVESİ (TEK KOLON / DURUM)

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
data["region"]=="Africa"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286     True
# 51287    False
# 51288    False
# 51289    False
# Name: region, Length: 51290, dtype: bool

# %%
data[data["region"]=="Africa"]  #applying filter with single condition
# Out:
#            order_id  order_date      segment      country  region  \
# 0      AG-2011-2040  01-01-2011     Consumer      Algeria  Africa
# 23     TZ-2011-7370  01-03-2011     Consumer     Tanzania  Africa
# 41     SU-2011-5190  01-04-2011     Consumer        Sudan  Africa
# 42     SU-2011-5190  01-04-2011     Consumer        Sudan  Africa
# 55     AO-2011-4910  01-06-2011    Corporate       Angola  Africa
# ...             ...         ...          ...          ...     ...
# 51252  OD-2014-9490  12/31/2014    Corporate  South Sudan  Africa
# 51253  AO-2014-7730  12/31/2014     Consumer       Angola  Africa
# 51262  TZ-2014-8350  12/31/2014     Consumer     Tanzania  Africa
# 51280  TZ-2014-8220  12/31/2014  Home Office     Tanzania  Africa
# 51286  MO-2014-2560  12/31/2014     Consumer      Morocco  Africa
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# 23     OFF-STI-10000388  Office Supplies
# 41     OFF-BOS-10004950  Office Supplies
# ...

# %% [markdown]
# FİLTER DATAFRAME (MULTİPLE COLUMNS / CONDİTİONS) - AND OPERATOR
#
# #FİLTRE VERİ ÇERÇEVESİ (ÇOK KOLON / KOŞULLAR) - VE OPERATÖR

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
(data["segment"]=="Corporate")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285     True
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: segment, Length: 51290, dtype: bool

# %%
(data["category"]=="Technology")
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: category, Length: 51290, dtype: bool

# %%
data[(data["segment"]=="Corporate") & (data["category"]=="Technology")]
# Out:
#              order_id  order_date    segment             country  \
# 28     MX-2011-140641  01-04-2011  Corporate              Mexico
# 32     MX-2011-140641  01-04-2011  Corporate              Mexico
# 55       AO-2011-4910  01-06-2011  Corporate              Angola
# 66       LE-2011-9590  01-07-2011  Corporate             Lebanon
# 92      ID-2011-20814  01-09-2011  Corporate           Indonesia
# ...               ...         ...        ...                 ...
# 51250   IN-2014-78228  12/31/2014  Corporate           Indonesia
# 51251  MX-2014-122511  12/31/2014  Corporate  Dominican Republic
# 51252    OD-2014-9490  12/31/2014  Corporate         South Sudan
# 51259  MX-2014-116267  12/31/2014  Corporate              Brazil
# 51275   ID-2014-54442  12/31/2014  Corporate         Philippines
#
#                region        product_id    category  \
# 28              North   TEC-AC-10001082  Technology
# 32              North   TEC-CO-10002998  Technology
# ...

# %% [markdown]
# FİLTER DATAFRAME (MULTİPLE COLUMNS / CONDİTİONS) - OR OPERATOR
#
# #FİLTRE VERİ ÇERÇEVESİ (ÇOK KOLON / KOŞULLAR) - OR OPERATÖR

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
data["country"]=="Canada"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: country, Length: 51290, dtype: bool

# %%
data[(data['country']=="Canada") | (data['sales'] )]
# Out:
#               order_id  order_date      segment        country   region  \
# 0         AG-2011-2040  01-01-2011     Consumer        Algeria   Africa
# 1        IN-2011-47883  01-01-2011     Consumer      Australia  Oceania
# 2         HU-2011-1220  01-01-2011     Consumer        Hungary     EMEA
# 3      IT-2011-3647632  01-01-2011  Home Office         Sweden    North
# 4        IN-2011-47883  01-01-2011     Consumer      Australia  Oceania
# ...                ...         ...          ...            ...      ...
# 51285   CA-2014-115427  12/31/2014    Corporate  United States     West
# 51286     MO-2014-2560  12/31/2014     Consumer        Morocco   Africa
# 51287   MX-2014-110527  12/31/2014     Consumer      Nicaragua  Central
# 51288   MX-2014-114783  12/31/2014     Consumer         Mexico    North
# 51289   CA-2014-156720  12/31/2014     Consumer  United States     West
#
#              product_id         category  \
# 0      OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# PİVOT TABLE

# %%
data.pivot_table(index='region',columns='year',values='sales')
# Out:
# C:\Users\SERKAN\AppData\Local\Temp\ipykernel_16424\992495976.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   data.pivot_table(index='region',columns='year',values='sales')
# Empty DataFrame
# Columns: []
# Index: [Africa, Canada, Caribbean, Central, Central Asia, EMEA, East, North, North Asia, Oceania, South, Southeast Asia, West]

# %%
data.pivot_table(columns="category",index="region",values="profit")
# Out:
# category         Furniture  Office Supplies  Technology
# region
# Africa           25.771926         9.353055   48.440717
# Canada           62.220000        28.727545  111.486462
# Caribbean        16.551755        15.229472   39.676202
# Central          26.662190        17.490588   63.484038
# Central Asia    102.375967        24.396490  122.962908
# EMEA             14.979397         4.509976   18.185492
# East              5.068496        23.957114   88.714084
# North            32.721765        22.101370  107.205714
# North Asia       99.964178        30.725304  149.733502
# Oceania          45.318644        16.984287   69.813804
# South            17.044114        16.686279   39.502863
# Southeast Asia  -10.581902         2.353780   31.313668
# West             16.272914        27.733183   73.962687

# %%
data.head(2)
# Out:
#         order_id  order_date   segment    country   region        product_id  \
# 0   AG-2011-2040  01-01-2011  Consumer    Algeria   Africa  OFF-TEN-10000025
# 1  IN-2011-47883  01-01-2011  Consumer  Australia  Oceania   OFF-SU-10000618
#
#           category              product_name sales  \
# 0  Office Supplies       Tenex Lockers, Blue   408
# 1  Office Supplies  Acme Trimmer, High Speed   120
#
#                                            new_sales  quantity  discount  \
# 0  4084084084084084084084084084084084084084084084...         2       0.0
# 1  1201201201201201201201201201201201201201201201...         3       0.1
#
#     profit  year  new_quantity
# 0  106.140  2011            20
# 1   36.036  2011            30

# %%
#showing Sum Of Values
data.pivot_table(columns="category",index="region",values="profit",aggfunc={"profit":"sum"})
# Out:
# category         Furniture  Office Supplies    Technology
# region
# Africa          16262.0850       28480.0530   44129.49300
# Canada           2613.2400        7957.5300    7246.62000
# Caribbean        6223.4600       14818.2760   13529.58504
# Central         54550.8401      121314.7209  135538.42064
# Central Asia    48935.7120       27104.5000   56439.97500
# EMEA            11534.1360       14869.3920   17494.44300
# East             3046.1658       41014.5791   47462.03510
# North           30922.0680       64403.3930   99272.49152
# North Asia      52181.3010       40926.1050   72471.01500
# Oceania         33626.4340       33306.1860   54734.02200
# South           22651.6281       67495.9988   50208.13928
# Southeast Asia  -7269.7665        4173.2515   20948.84400
# West            11504.9503       52609.8490   44303.64960

# %% [markdown]
# SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data.sales,data["profit"],color="red",s=40,edgecolors="purple",label="profit")
plt.legend()
plt.xlabel("Sales"),plt.ylabel("Profit")
plt.show()

# %% [markdown]
# CONCATENATE 2 COLUMNS
#
# #2 KOLONU BİRLEŞTİR

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
data["concat"]=data["country"] + data["region"]

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...

# %%
data["concat"]=data["country"] + "(" + data["region"]+ ")"

# %%
data.head()
# Out:
#           order_id  order_date      segment    country   region  \
# 0     AG-2011-2040  01-01-2011     Consumer    Algeria   Africa
# 1    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
# 2     HU-2011-1220  01-01-2011     Consumer    Hungary     EMEA
# 3  IT-2011-3647632  01-01-2011  Home Office     Sweden    North
# 4    IN-2011-47883  01-01-2011     Consumer  Australia  Oceania
#
#          product_id         category                 product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed   120
# 2  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width    66
# 3   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium    45
# 4   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack   114
#
#                                            new_sales  quantity  discount  \
# ...
