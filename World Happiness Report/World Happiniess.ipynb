# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# 1.Soru : Ülkemiz Türkiye'yi baz alacak olursak; 2015-2019 yılları arasında insanların mutlu olmasına etki eden faktörler yıllara göre neler ve zamanla nasıl değişmiş?

# %%
df_2015=pd.read_csv("2015.csv")
df_2016=pd.read_csv("2016.csv")
df_2017=pd.read_csv("2017.csv")
df_2018=pd.read_csv("2018.csv")
df_2019=pd.read_csv("2019.csv")

# %%
df_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_2015.shape
# Out:
# (158, 12)

# %%
df_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df_2016.shape
# Out:
# (157, 13)

# %%
df_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df_2017.shape
# Out:
# (155, 12)

# %%
df_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
df_2018.shape
# Out:
# (156, 9)

# %%
df_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
df_2019.shape
# Out:
# (156, 9)

# %%
df_2015["Year"]=2015
df_2016["Year"]=2016
df_2017["Year"]=2017
df_2018["Year"]=2018
df_2019["Year"]=2019

# %%
df_2015.isnull().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Standard Error                   False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                False
# Year                             False
# dtype: bool

# %%
df_2016.isnull().any()
# Out:
# Country                          False
# Region                           False
# Happiness Rank                   False
# Happiness Score                  False
# Lower Confidence Interval        False
# Upper Confidence Interval        False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)    False
# Generosity                       False
# Dystopia Residual                False
# Year                             False
# dtype: bool

# %%
df_2017.isnull().any()
# Out:
# Country                          False
# Happiness.Rank                   False
# Happiness.Score                  False
# Whisker.high                     False
# Whisker.low                      False
# Economy..GDP.per.Capita.         False
# Family                           False
# Health..Life.Expectancy.         False
# Freedom                          False
# Generosity                       False
# Trust..Government.Corruption.    False
# Dystopia.Residual                False
# Year                             False
# dtype: bool

# %%
df_2018.isnull().any() #Perceptions of corruption        True
# Out:
# Overall rank                    False
# Country or region               False
# Score                           False
# GDP per capita                  False
# Social support                  False
# Healthy life expectancy         False
# Freedom to make life choices    False
# Generosity                      False
# Perceptions of corruption        True
# Year                            False
# dtype: bool

# %%
df_2019.isnull().any()
# Out:
# Overall rank                    False
# Country or region               False
# Score                           False
# GDP per capita                  False
# Social support                  False
# Healthy life expectancy         False
# Freedom to make life choices    False
# Generosity                      False
# Perceptions of corruption       False
# Year                            False
# dtype: bool

# %%
df_c1=pd.concat([df_2015,df_2016,df_2017])

# %%
df_c1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %%
df_c1.tail()
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 150                    Rwanda    NaN             NaN              NaN
# 151                     Syria    NaN             NaN              NaN
# 152                  Tanzania    NaN             NaN              NaN
# 153                   Burundi    NaN             NaN              NaN
# 154  Central African Republic    NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 150             NaN                       NaN  0.945707
# 151             NaN                       NaN  0.396103
# 152             NaN                       NaN  1.041990
# 153             NaN                       NaN  0.629794
# 154             NaN                       NaN  0.000000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  ...  \
# 150                       NaN  0.581844                            NaN  ...
# ...

# %%
df_c2=pd.concat([df_2018,df_2019])

# %%
df_c2.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption  Year
# 0                      0.393  2018
# 1                      0.340  2018
# ...

# %%
df_c2.tail()
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 151           0.711                    0.614                         0.555
# 152           0.885                    0.499                         0.417
# 153           0.517                    0.361                         0.000
# 154           0.000                    0.105                         0.225
# 155           0.575                    0.295                         0.010
#
#      Generosity  Perceptions of corruption  Year
# 151       0.217                      0.411  2019
# ...

# %%
df_c1.isnull().any()
# Out:
# Country                          False
# Region                            True
# Happiness Rank                    True
# Happiness Score                   True
# Standard Error                    True
# Economy (GDP per Capita)          True
# Family                           False
# Health (Life Expectancy)          True
# Freedom                          False
# Trust (Government Corruption)     True
# Generosity                       False
# Dystopia Residual                 True
# Year                             False
# Lower Confidence Interval         True
# Upper Confidence Interval         True
# Happiness.Rank                    True
# Happiness.Score                   True
# Whisker.high                      True
# Whisker.low                       True
# Economy..GDP.per.Capita.          True
# Health..Life.Expectancy.          True
# Trust..Government.Corruption.     True
# Dystopia.Residual                 True
# dtype: bool

# %%
df_c1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# ...

# %%
df_c1.shape
# Out:
# (470, 23)

# %%
df_c1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year', 'Lower Confidence Interval',
#        'Upper Confidence Interval', 'Happiness.Rank', 'Happiness.Score',
#        'Whisker.high', 'Whisker.low', 'Economy..GDP.per.Capita.',
#        'Health..Life.Expectancy.', 'Trust..Government.Corruption.',
#        'Dystopia.Residual'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")

scores_15_16=df_c1["Happiness Score"].dropna()
scores_17=df_c1["Happiness.Score"].dropna()
appended=scores_15_16.append(scores_17)
df_c1["Happiness Score"]=appended
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [60], in <module>
#       5 scores_17=df_c1["Happiness.Score"].dropna()
#       6 appended=scores_15_16.append(scores_17)
# ----> 7 df_c1["Happiness Score"]=appended
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
# ...

# %%
appended
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.471
# 151    3.462
# 152    3.349
# 153    2.905
# 154    2.693
# Length: 625, dtype: float64

# %%
df_c1.shape
# Out:
# (470, 23)

# %%
df_c1.tail()
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 150                    Rwanda    NaN             NaN              NaN
# 151                     Syria    NaN             NaN              NaN
# 152                  Tanzania    NaN             NaN              NaN
# 153                   Burundi    NaN             NaN              NaN
# 154  Central African Republic    NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 150             NaN                       NaN  0.945707
# 151             NaN                       NaN  0.396103
# 152             NaN                       NaN  1.041990
# 153             NaN                       NaN  0.629794
# 154             NaN                       NaN  0.000000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  ...  \
# 150                       NaN  0.581844                            NaN  ...
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

economy_15_16=df_c1["Economy (GDP per Capita)"].dropna()
economy_17=df_c1["Economy..GDP.per.Capita."].dropna()
appended=economy_15_16.append(economy_17)
df_c1["Economy (GDP per Capita)"]=appended

# %%
import warnings
warnings.filterwarnings("ignore")

health_15_16=df_c1["Health (Life Expectancy)"].dropna()
health_17=df_c1["Health..Life.Expectancy."].dropna()
appended=health_15_16.append(health_17)
df_c1["Health (Life Expectancy)"]=appended

# %%
import warnings
warnings.filterwarnings("ignore")

dystopia_15_16=df_c1["Dystopia Residual"].dropna()
dystopia_17=df_c1["Dystopia.Residual"].dropna()
appended=dystopia_15_16.append(dystopia_17)
df_c1["Dystopia Residual"]=appended

# %%
import warnings
warnings.filterwarnings("ignore")

goverment_15_16=df_c1["Trust (Government Corruption)"].dropna()
goverment_17=df_c1["Trust..Government.Corruption."].dropna()
appended=goverment_15_16.append(goverment_17)
df_c1["Trust (Government Corruption)"]=appended

# %%
import warnings
warnings.filterwarnings("ignore")

happiniess_15_16=df_c1["Happiness Rank"].dropna()
happiniess_17=df_c1["Trust..Government.Corruption."].dropna()
appended=happiniess_15_16.append(happiniess_17)
df_c1["Happiness.Rank"]=appended

# %%
df_c1.drop(columns=["Happiness.Score","Happiness.Rank",
                    "Economy..GDP.per.Capita.",
                    "Health..Life.Expectancy.",
                    "Dystopia.Residual","Trust..Government.Corruption."],inplace=True)

# %%
df_c1.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual', 'Year', 'Lower Confidence Interval',
#        'Upper Confidence Interval', 'Whisker.high', 'Whisker.low'],
#       dtype='object')

# %%
df_c1.drop(["Lower Confidence Interval","Upper Confidence Interval","Whisker.high","Whisker.low"],inplace=True,axis=1)

# %%
df_c1.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe             1.0            7.587
# 1      Iceland  Western Europe             2.0            7.561
# 2      Denmark  Western Europe             3.0            7.527
# 3       Norway  Western Europe             4.0            7.522
# 4       Canada   North America             5.0            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df_c1.tail()
# Out:
#                       Country Region  Happiness Rank  Happiness Score  \
# 150                    Rwanda    NaN             NaN            3.471
# 151                     Syria    NaN             NaN            3.462
# 152                  Tanzania    NaN             NaN            3.349
# 153                   Burundi    NaN             NaN            2.905
# 154  Central African Republic    NaN             NaN            2.693
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 150             NaN                  0.368746  0.945707
# 151             NaN                  0.777153  0.396103
# 152             NaN                  0.511136  1.041990
# 153             NaN                  0.091623  0.629794
# 154             NaN                  0.000000  0.000000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 150                  0.326425  0.581844                       0.455220
# ...

# %%
df_c1.drop(["Region"],axis=1,inplace=True)

# %%
df_c1.tail()
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 150                    Rwanda             NaN            3.471
# 151                     Syria             NaN            3.462
# 152                  Tanzania             NaN            3.349
# 153                   Burundi             NaN            2.905
# 154  Central African Republic             NaN            2.693
#
#      Standard Error  Economy (GDP per Capita)    Family  \
# 150             NaN                  0.368746  0.945707
# 151             NaN                  0.777153  0.396103
# 152             NaN                  0.511136  1.041990
# 153             NaN                  0.091623  0.629794
# 154             NaN                  0.000000  0.000000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 150                  0.326425  0.581844                       0.455220
# 151                  0.500533  0.081539                       0.151347
# ...

# %%
df_c1.drop(["Standard Error"],axis=1,inplace=True)

# %%
df_c1.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland             1.0            7.587                   1.39651
# 1      Iceland             2.0            7.561                   1.30232
# 2      Denmark             3.0            7.527                   1.32548
# 3       Norway             4.0            7.522                   1.45900
# 4       Canada             5.0            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual  Year
# ...

# %%
df_c1.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual', 'Year'],
#       dtype='object')

# %%
df_c2.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Year'],
#       dtype='object')

# %%
df_c2.columns=['Happiness Rank','Country','Happiness Score', 'Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Generosity','Trust (Government Corruption)','Year']

# %%
df_c2.head()
# Out:
#    Happiness Rank      Country  Happiness Score  Economy (GDP per Capita)  \
# 0               1      Finland            7.632                     1.305
# 1               2       Norway            7.594                     1.456
# 2               3      Denmark            7.555                     1.351
# 3               4      Iceland            7.495                     1.343
# 4               5  Switzerland            7.487                     1.420
#
#    Family  Health (Life Expectancy)  Freedom  Generosity  \
# 0   1.592                     0.874    0.681       0.202
# 1   1.582                     0.861    0.686       0.286
# 2   1.590                     0.868    0.683       0.284
# 3   1.644                     0.914    0.677       0.353
# 4   1.549                     0.927    0.660       0.256
#
#    Trust (Government Corruption)  Year
# 0                          0.393  2018
# 1                          0.340  2018
# 2                          0.408  2018
# ...

# %%
df=df_c1.append(df_c2)

# %%
df.tail()
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 151                    Rwanda           152.0            3.334
# 152                  Tanzania           153.0            3.231
# 153               Afghanistan           154.0            3.203
# 154  Central African Republic           155.0            3.083
# 155               South Sudan           156.0            2.853
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 151                     0.359   0.711                     0.614    0.555
# 152                     0.476   0.885                     0.499    0.417
# 153                     0.350   0.517                     0.361    0.000
# 154                     0.026   0.000                     0.105    0.225
# 155                     0.306   0.575                     0.295    0.010
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 151                          0.411       0.217                NaN  2019
# ...

# %%
df.drop(["Dystopia Residual"],axis=1,inplace=True)

# %%
df.isnull().any()
# Out:
# Country                          False
# Happiness Rank                    True
# Happiness Score                  False
# Economy (GDP per Capita)         False
# Family                           False
# Health (Life Expectancy)         False
# Freedom                          False
# Trust (Government Corruption)     True
# Generosity                       False
# Year                             False
# dtype: bool

# %%
df.isnull().any().sum()
# Out:
# 2

# %%
from ycimpute.imputer import knnimput

# %%
df["IsTurkey"]=df["IsTurkey"].astype("int16")

# %%
df.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland             1.0            7.587                   1.39651
# 1      Iceland             2.0            7.561                   1.30232
# 2      Denmark             3.0            7.527                   1.32548
# 3       Norway             4.0            7.522                   1.45900
# 4       Canada             5.0            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Year  IsTurkey
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        782 non-null    object
#  1   Happiness Rank                 627 non-null    float64
#  2   Happiness Score                782 non-null    float64
#  3   Economy (GDP per Capita)       782 non-null    float64
#  4   Family                         782 non-null    float64
#  5   Health (Life Expectancy)       782 non-null    float64
#  6   Freedom                        782 non-null    float64
#  7   Trust (Government Corruption)  781 non-null    float64
#  8   Generosity                     782 non-null    float64
#  9   Year                           782 non-null    int64
#  10  IsTurkey                       782 non-null    int16
# dtypes: float64(8), int16(1), int64(1), object(1)
# memory usage: 84.9+ KB

# %%
df_numerical=df.select_dtypes(include=["float64","int64","int16"])

# %%
knned_df_numerical=np.array(df_numerical)

# %%
knned_df_numerical
# Out:
# array([[1.00000e+00, 7.58700e+00, 1.39651e+00, ..., 2.96780e-01,
#         2.01500e+03, 0.00000e+00],
#        [2.00000e+00, 7.56100e+00, 1.30232e+00, ..., 4.36300e-01,
#         2.01500e+03, 0.00000e+00],
#        [3.00000e+00, 7.52700e+00, 1.32548e+00, ..., 3.41390e-01,
#         2.01500e+03, 0.00000e+00],
#        ...,
#        [1.54000e+02, 3.20300e+00, 3.50000e-01, ..., 1.58000e-01,
#         2.01900e+03, 0.00000e+00],
#        [1.55000e+02, 3.08300e+00, 2.60000e-02, ..., 2.35000e-01,
#         2.01900e+03, 0.00000e+00],
#        [1.56000e+02, 2.85300e+00, 3.06000e-01, ..., 2.02000e-01,
#         2.01900e+03, 0.00000e+00]])

# %%
knned_np=knnimput.KNN(k=4).complete(knned_df_numerical)
# Out:
# Imputing row 1/782 with 0 missing, elapsed time: 0.053
# Imputing row 101/782 with 0 missing, elapsed time: 0.053
# Imputing row 201/782 with 0 missing, elapsed time: 0.053
# Imputing row 301/782 with 0 missing, elapsed time: 0.053
# Imputing row 401/782 with 1 missing, elapsed time: 0.055
# Imputing row 501/782 with 0 missing, elapsed time: 0.056
# Imputing row 601/782 with 0 missing, elapsed time: 0.056
# Imputing row 701/782 with 0 missing, elapsed time: 0.056

# %%
type(knned_np)
# Out:
# numpy.ndarray

# %%
knned_np
# Out:
# array([[1.00000e+00, 7.58700e+00, 1.39651e+00, ..., 2.96780e-01,
#         2.01500e+03, 0.00000e+00],
#        [2.00000e+00, 7.56100e+00, 1.30232e+00, ..., 4.36300e-01,
#         2.01500e+03, 0.00000e+00],
#        [3.00000e+00, 7.52700e+00, 1.32548e+00, ..., 3.41390e-01,
#         2.01500e+03, 0.00000e+00],
#        ...,
#        [1.54000e+02, 3.20300e+00, 3.50000e-01, ..., 1.58000e-01,
#         2.01900e+03, 0.00000e+00],
#        [1.55000e+02, 3.08300e+00, 2.60000e-02, ..., 2.35000e-01,
#         2.01900e+03, 0.00000e+00],
#        [1.56000e+02, 2.85300e+00, 3.06000e-01, ..., 2.02000e-01,
#         2.01900e+03, 0.00000e+00]])

# %%
knned_df=pd.DataFrame(knned_np,columns=df_numerical.columns)

# %%
knned_df
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0               1.0            7.587                   1.39651  1.34951
# 1               2.0            7.561                   1.30232  1.40223
# 2               3.0            7.527                   1.32548  1.36058
# 3               4.0            7.522                   1.45900  1.33095
# 4               5.0            7.427                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 777           152.0            3.334                   0.35900  0.71100
# 778           153.0            3.231                   0.47600  0.88500
# 779           154.0            3.203                   0.35000  0.51700
# 780           155.0            3.083                   0.02600  0.00000
# 781           156.0            2.853                   0.30600  0.57500
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
knned_df.isnull().sum()
# Out:
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Year                             0
# IsTurkey                         0
# dtype: int64

# %%
knned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Happiness Rank                 782 non-null    float64
#  1   Happiness Score                782 non-null    float64
#  2   Economy (GDP per Capita)       782 non-null    float64
#  3   Family                         782 non-null    float64
#  4   Health (Life Expectancy)       782 non-null    float64
#  5   Freedom                        782 non-null    float64
#  6   Trust (Government Corruption)  782 non-null    float64
#  7   Generosity                     782 non-null    float64
#  8   Year                           782 non-null    float64
#  9   IsTurkey                       782 non-null    float64
# dtypes: float64(10)
# memory usage: 61.2 KB

# %%
df_turkey=knned_df[knned_df["IsTurkey"]==1.0]

# %%
df_turkey
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 75        76.000000            5.332                  1.060980  0.946320
# 235       78.000000            5.389                  1.164920  0.877170
# 383       75.833474            5.500                  1.198274  1.337753
# 543       74.000000            5.483                  1.148000  1.380000
# 704       79.000000            5.373                  1.183000  1.360000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 75                   0.731720  0.228150                       0.157460
# 235                  0.647180  0.238890                       0.123480
# 383                  0.637606  0.300741                       0.099672
# 543                  0.686000  0.324000                       0.109000
# 704                  0.808000  0.195000                       0.106000
#
#      Generosity    Year  IsTurkey
# 75     0.122530  2015.0       1.0
# ...

# %%
df_turkey.drop(["IsTurkey"],axis=1,inplace=True)

# %%
df_turkey
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)    Family  \
# 75        76.000000            5.332                  1.060980  0.946320
# 235       78.000000            5.389                  1.164920  0.877170
# 383       75.833474            5.500                  1.198274  1.337753
# 543       74.000000            5.483                  1.148000  1.380000
# 704       79.000000            5.373                  1.183000  1.360000
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# 75                   0.731720  0.228150                       0.157460
# 235                  0.647180  0.238890                       0.123480
# 383                  0.637606  0.300741                       0.099672
# 543                  0.686000  0.324000                       0.109000
# 704                  0.808000  0.195000                       0.106000
#
#      Generosity    Year
# 75     0.122530  2015.0
# 235    0.047070  2016.0
# ...

# %%
df_turkey.groupby("Happiness Score").sum().Year.plot()
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %%
df_turkey.groupby("Year").sum()["Happiness Score"].plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
sns.barplot(x="Year",y="Happiness Score",data=df_turkey)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Happiness Score'>

# %%
df_turkey.groupby("Happiness Score").mean().T
# Out:
# Happiness Score                     5.332     5.373       5.389     5.483  \
# Happiness Rank                   76.00000    79.000    78.00000    74.000
# Economy (GDP per Capita)          1.06098     1.183     1.16492     1.148
# Family                            0.94632     1.360     0.87717     1.380
# Health (Life Expectancy)          0.73172     0.808     0.64718     0.686
# Freedom                           0.22815     0.195     0.23889     0.324
# Trust (Government Corruption)     0.15746     0.106     0.12348     0.109
# Generosity                        0.12253     0.083     0.04707     0.106
# Year                           2015.00000  2019.000  2016.00000  2018.000
#
# Happiness Score                      5.500
# Happiness Rank                   75.833474
# Economy (GDP per Capita)          1.198274
# Family                            1.337753
# Health (Life Expectancy)          0.637606
# Freedom                           0.300741
# ...

# %% [markdown]
# 2.Soru : Sadece 2019 verisini baz alırsak; 2019 yılındaki en mutlu ülke hangisidir? Hangi faktör/faktörler en mutlu ülke olmasını sağlamış olabilir? Görselleştirerek ifade etmenizi bekliyoruz.

# %%
df_turkey_score_grouped=df_turkey.groupby("Happiness Score").sum()
# Out:
#                  Happiness Rank  Economy (GDP per Capita)    Family  \
# Happiness Score
# 5.332                 76.000000                  1.060980  0.946320
# 5.373                 79.000000                  1.183000  1.360000
# 5.389                 78.000000                  1.164920  0.877170
# 5.483                 74.000000                  1.148000  1.380000
# 5.500                 75.833474                  1.198274  1.337753
#
#                  Health (Life Expectancy)   Freedom  \
# Happiness Score
# 5.332                            0.731720  0.228150
# 5.373                            0.808000  0.195000
# 5.389                            0.647180  0.238890
# 5.483                            0.686000  0.324000
# 5.500                            0.637606  0.300741
#
#                  Trust (Government Corruption)  Generosity    Year
# Happiness Score
# 5.332                                 0.157460    0.122530  2015.0
# ...

# %%
df_turkey_score_grouped
# Out:
#                  Happiness Rank  Economy (GDP per Capita)    Family  \
# Happiness Score
# 5.332                 76.000000                  1.060980  0.946320
# 5.373                 79.000000                  1.183000  1.360000
# 5.389                 78.000000                  1.164920  0.877170
# 5.483                 74.000000                  1.148000  1.380000
# 5.500                 75.833474                  1.198274  1.337753
#
#                  Health (Life Expectancy)   Freedom  \
# Happiness Score
# 5.332                            0.731720  0.228150
# 5.373                            0.808000  0.195000
# 5.389                            0.647180  0.238890
# 5.483                            0.686000  0.324000
# 5.500                            0.637606  0.300741
#
#                  Trust (Government Corruption)  Generosity    Year
# Happiness Score
# 5.332                                 0.157460    0.122530  2015.0
# ...

# %%
sns.pairplot(df_turkey_score_grouped)

# %%
df_turkey.plot(x="Happiness Score",subplots=True,layout=(10,4),legend=True,figsize=(30,60))
# Out:
# array([[<AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>],
#        [<AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>],
#        [<AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>],
#        [<AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>],
#        [<AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
#         <AxesSubplot:xlabel='Happiness Score'>,
# ...

# %%
happiest_2019=df_2019[df_2019["Score"]==df_2019["Score"].max()]

# %%
happiest_2019
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption  Year
# 0                      0.393  2019

# %%
happiest_2018=df_2018[df_2018["Score"]==df_2018["Score"].max()]

# %%
happiest_2018
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
#
#    Perceptions of corruption  Year
# 0                      0.393  2018

# %%
happiest_2019_Other_Step=df_2019[df_2019["Overall rank"]==1]

# %%
happiest_2019_Other_Step
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769            1.34           1.587
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
#
#    Perceptions of corruption  Year
# 0                      0.393  2019

# %%
X=happiest_2019[["GDP per capita","Social support","Healthy life expectancy","Freedom to make life choices","Generosity","Perceptions of corruption"]]

# %%
X
# Out:
#    GDP per capita  Social support  Healthy life expectancy  \
# 0            1.34           1.587                    0.986
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393

# %%
melted_df_X=pd.melt(X)

# %%
melted_df_X
# Out:
#                        variable  value
# 0                GDP per capita  1.340
# 1                Social support  1.587
# 2       Healthy life expectancy  0.986
# 3  Freedom to make life choices  0.596
# 4                    Generosity  0.153
# 5     Perceptions of corruption  0.393

# %%
sns.barplot(y=melted_df_X.variable,x=melted_df_X.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='variable'>

# %%
melted_df_X_sorted=melted_df_X.sort_values(by=["value"],ascending=True)

# %%
sns.barplot(y=melted_df_X_sorted.variable,x=melted_df_X.value)
# Out:
# <AxesSubplot:xlabel='value', ylabel='variable'>

# %%
def plot_usa_case_map(filename=None, day=None):
	df = load_relevant_data()
	dates = list(df.columns)
	df = df.groupby('Province_State')[dates].agg('sum')
	create_usa_figure(df, filename, day)
